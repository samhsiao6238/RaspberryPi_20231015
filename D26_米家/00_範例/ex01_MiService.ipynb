# %% [markdown]
# 安裝套件

# %%
# %pip install -q aiohttp aiofiles pandas python-dotenv openpyxl
# %pip install -q miservice --no-build-isolation

# %% [markdown]
# 建立環境變數

# %%
from dotenv import load_dotenv
import os

# 載入環境變數
load_dotenv()

# 讀取變數
mi_user = os.getenv('MI_USER')
mi_pass = os.getenv('MI_PASS')
mi_did = os.getenv('MI_DID')
openai_api_key = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# 查詢米家設備清單

# %%
# !micli.py list
# Out:
# [
#   {
#     "name": "客廳監視器",
#     "model": "chuangmi.camera.069a01",
#     "did": "1073582979",
#     "token": "6574475670786245436e5a61797a7770"
#   },
#   {
#     "name": "車庫監視器",
#     "model": "chuangmi.camera.069a01",
#     "did": "1073752199",
#     "token": "757173436f57515a4a6b66347a394e4e"
#   },
#   {
#     "name": "房間監視器",
#     "model": "chuangmi.camera.069a01",
#     "did": "1073775259",
#     "token": "37307938327a456d71706b32564e7a6b"
#   },
#   {
#     "name": "房間監視器",
#     "model": "chuangmi.camera.061a01",
#     "did": "1104575738",
#     "token": "4a636767467335397247434a65586163"
#   },
#   {
#     "name": "新莊客廳監視器",
#     "model": "chuangmi.camera.061a01",
#     "did": "1104576170",
#     "token": "737a4f37596e6e4633343771684a3764"
#   },
#   {
#     "name": "客廳監視器",
#     "model": "chuangmi.camera.ipc009",
#     "did": "253578630",
#     "token": "6a444371457065716657566f586c6b45"
#   },
#   {
#     "name": "地下室監視器",
#     "model": "chuangmi.camera.v2",
#     "did": "66306142",
#     "token": "646f416e5646624f4b345a384a763170"
#   },
#   {
#     "name": "地下室小米盒子",
#     "model": "xiaomi.tvbox.v1",
#     "did": "mitv.2b8db7e80725257f950e5ee03b17745b:feaa090fe7734df19b29cfa1bdcb7832",
#     "token": "664b51475553464b354c65556d746259"
#   },
#   {
#     "name": "書桌多功能網關2",
#     "model": "lumi.gateway.mgl03",
#     "did": "463733386",
#     "token": "34434445514c74766a5050776f367965"
#   },
#   {
#     "name": "廚房按鈕",
#     "model": "lumi.sensor_switch.v2",
#     "did": "lumi.158d0006ba2f0b",
#     "token": ""
#   },
#   {
#     "name": "沙發按鈕",
#     "model": "lumi.sensor_switch.v2",
#     "did": "lumi.158d0007c10297",
#     "token": ""
#   },
#   {
#     "name": "夜燈",
#     "model": "philips.light.downlight",
#     "did": "248430074",
#     "token": "a69edfb35d36afbf8b784977511d679e"
#   },
#   {
#     "name": "夜燈",
#     "model": "philips.light.downlight",
#     "did": "248515918",
#     "token": "c3951a9b87d77515d20e8012c65f00d4"
#   },
#   {
#     "name": "筒燈",
#     "model": "yeelink.light.light3",
#     "did": "1102013128",
#     "token": "0a8e968a5cfe3efa3ba62119ed9b843e"
#   },
#   {
#     "name": "掃地機器人",
#     "model": "dreame.vacuum.p2149o",
#     "did": "1027048772",
#     "token": "46684b766e416135755a41787731324f"
#   },
#   {
#     "name": "後門門鈴",
#     "model": "madv.cateye.miowl3",
#     "did": "1033622627",
#     "token": "e3eb51c3b13dd7e604074f439e75c7ea"
#   },
#   {
#     "name": "鋼琴燈",
#     "model": "lemesh.light.wy0c02",
#     "did": "1060040685",
#     "token": "a7b120a1d2e1eb2c503df727498d5b93"
#   },
#   {
#     "name": "小台燈",
#     "model": "lemesh.light.wy0c02",
#     "did": "1060040723",
#     "token": "8b632df7bda6aeda818cf489e773d8aa"
#   },
#   {
#     "name": "夜燈",
#     "model": "lemesh.light.wy0c02",
#     "did": "1060040989",
#     "token": "d2e8dd5ea38c91fceecb59399bcb07cb"
#   },
#   {
#     "name": "桌燈",
#     "model": "lemesh.light.wy0c02",
#     "did": "1060078226",
#     "token": "d1d3512acfe29a7240761e25a2076ee8"
#   },
#   {
#     "name": "警示燈-客廳",
#     "model": "lemesh.light.wy0c02",
#     "did": "1060078229",
#     "token": "79030727bb9336e458c3731417c2adff"
#   },
#   {
#     "name": "大台燈",
#     "model": "lemesh.light.wy0c02",
#     "did": "1060078434",
#     "token": "9a439e23f800448c65fb6034a25b93da"
#   },
#   {
#     "name": "麻將燈",
#     "model": "lemesh.light.wy0c02",
#     "did": "1060078455",
#     "token": "dfa6eeb5ed3813731a93292867e94d15"
#   },
#   {
#     "name": "桌燈",
#     "model": "lemesh.light.wy0c02",
#     "did": "1060078468",
#     "token": "ffaf0ff4b192c4dc55e3a4a7bf294c98"
#   },
#   {
#     "name": "夜燈",
#     "model": "lemesh.light.wy0c02",
#     "did": "1060487219",
#     "token": "3799eb2f0e5d9f030c0ba74c4bb0b502"
#   },
#   {
#     "name": "吊燈",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060510690",
#     "token": "49271c7127f8ae2f06117582c5dcb1f1"
#   },
#   {
#     "name": "迎賓燈",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060510763",
#     "token": "6a9b29adb11eb756466b81eb4d865e12"
#   },
#   {
#     "name": "間接燈",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060510786",
#     "token": "b2fb90ddcb975e13238d163c20c8fc1a"
#   },
#   {
#     "name": "風扇",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060512499",
#     "token": "f726430a7e38be7d237858f223cd4ab3"
#   },
#   {
#     "name": "樓台四號燈",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060527720",
#     "token": "dc5989e0bd17413d93a19bac42bde0bf"
#   },
#   {
#     "name": "前燈",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060531701",
#     "token": "2ce386b357fd6f72619af24e447376ec"
#   },
#   {
#     "name": "電視燈",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060536774",
#     "token": "dc886a002d5595a96774154be78edf25"
#   },
#   {
#     "name": "夜燈",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060536895",
#     "token": "aac53cad25834c8dde870c000c151703"
#   },
#   {
#     "name": "鞋櫃燈",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060536920",
#     "token": "409d91753508cd1ae3c827f5475134f8"
#   },
#   {
#     "name": "洗碗燈",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060536927",
#     "token": "865ce1325bc95386dc91b335d7aba188"
#   },
#   {
#     "name": "壁燈",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060537815",
#     "token": "dfbd9b97a9d9a89d54317de20057d403"
#   },
#   {
#     "name": "大燈",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060539358",
#     "token": "2498cee123148117336a301886ad678e"
#   },
#   {
#     "name": "後燈",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060540234",
#     "token": "455cac54bb0c23845371b68b3cdbdceb"
#   },
#   {
#     "name": "露台一號燈",
#     "model": "lemesh.switch.sw0a01",
#     "did": "1060540295",
#     "token": "10f4e8e7da74413d3229169447c0bf49"
#   },
#   {
#     "name": "萬能遙控",
#     "model": "chuangmi.remote.v2",
#     "did": "106211175",
#     "token": "673fd9069b0139d9aba20cbca3a48973"
#   },
#   {
#     "name": "浴室門鎖",
#     "model": "line.lock.fms5",
#     "did": "1065012196",
#     "token": "cc8f9958ecdc5509d997905c"
#   },
#   {
#     "name": "主臥房",
#     "model": "line.lock.fms5",
#     "did": "1065015054",
#     "token": "839b48fcc0ef46f7ebca8110"
#   },
#   {
#     "name": "掃地機器人",
#     "model": "xiaomi.vacuum.c107",
#     "did": "1065409696",
#     "token": "7248647646486e77684f636d49714667"
#   },
#   {
#     "name": "掃地機器人",
#     "model": "xiaomi.vacuum.c107",
#     "did": "1065813489",
#     "token": "496c614657516153564167774a684673"
#   },
#   {
#     "name": "雙眼二",
#     "model": "isa.camera.hlmax",
#     "did": "1065928047",
#     "token": "646e6e444548755a474249384b4a714c"
#   },
#   {
#     "name": "露台監視器",
#     "model": "isa.camera.hlmax",
#     "did": "1065928966",
#     "token": "3573366b6865366678556b4345723136"
#   },
#   {
#     "name": "小愛音箱",
#     "model": "xiaomi.wifispeaker.x10a",
#     "did": "1071456378",
#     "token": "5431335151686d625966527264564b48"
#   },
#   {
#     "name": "電視燈",
#     "model": "ftd.light.dsplmp",
#     "did": "1085992686",
#     "token": "a0c8c6d06c16b4fadc3a015bad7b5221"
#   },
#   {
#     "name": "主燈",
#     "model": "ftd.light.dsplmp",
#     "did": "1085992703",
#     "token": "c2315a9898dfac6ea6b3452874938d42"
#   },
#   {
#     "name": "前輔助燈",
#     "model": "ftd.light.dsplmp",
#     "did": "1086036200",
#     "token": "e587df8f7cae7e991e602a305e3f1767"
#   },
#   {
#     "name": "洗衣間燈",
#     "model": "ftd.light.dsplmp",
#     "did": "1087747293",
#     "token": "8db3f8493377277a4ec41c6bbfb2e7ee"
#   },
#   {
#     "name": "後輔助燈",
#     "model": "ftd.light.dsplmp",
#     "did": "1087747348",
#     "token": "d305bb7dfe52274469929e3ac58fd2af"
#   },
#   {
#     "name": "大燈",
#     "model": "lemesh.switch.sw0a04",
#     "did": "1100093235",
#     "token": "5cb170d5010a9ccb6dc3b643e1753266"
#   },
#   {
#     "name": "淋浴間大燈",
#     "model": "lemesh.switch.sw0a04",
#     "did": "1100170930",
#     "token": "ec0046a57d5e4ec0cedcd5c1b42d8772"
#   },
#   {
#     "name": "客廳中樞",
#     "model": "xiaomi.gateway.hub1",
#     "did": "1104517967",
#     "token": "436b6a53766249423747365432655866"
#   },
#   {
#     "name": "鞋櫃下燈",
#     "model": "lemesh.switch.sw0a04",
#     "did": "1115599317",
#     "token": "3a16565520f0f3a885688a0f0d02716c"
#   },
#   {
#     "name": "露台二號燈",
#     "model": "lemesh.switch.sw0a04",
#     "did": "1115689600",
#     "token": "f8e4834c5dd1b9462455601ae616068c"
#   },
#   {
#     "name": "沙發前燈",
#     "model": "ftd.light.dsplmp",
#     "did": "1117095849",
#     "token": "cd030be6f13b3fbd9c1da1d0b49ae207"
#   },
#   {
#     "name": "沙發後燈",
#     "model": "ftd.light.dsplmp",
#     "did": "1117096491",
#     "token": "e48fe757f388b371658542a1a6b89418"
#   },
#   {
#     "name": "遙控器",
#     "model": "chuangmi.remote.v2",
#     "did": "124266410",
#     "token": "de0eff7e3e2ca04d79397b8b4974c1e3"
#   },
#   {
#     "name": "小愛-新莊臥房",
#     "model": "xiaomi.wifispeaker.s12",
#     "did": "286052675",
#     "token": "4c64616a5231734a32557356564d334d"
#   },
#   {
#     "name": "小愛-地下室",
#     "model": "xiaomi.wifispeaker.lx06",
#     "did": "319695299",
#     "token": "7044516455505337514461596b645037"
#   },
#   {
#     "name": "小愛-客廳",
#     "model": "xiaomi.wifispeaker.lx06",
#     "did": "319865370",
#     "token": "6a5131545736327550786f6e43657257"
#   },
#   {
#     "name": "除濕棒",
#     "model": "leshi.switch.v002",
#     "did": "362589988",
#     "token": "10a5828febfd8c3961bd203bc044f7e9"
#   },
#   {
#     "name": "夜燈",
#     "model": "julun.switch.jlsw01",
#     "did": "372816634",
#     "token": "e6ca8985b9bac40b37872e4254cd584f"
#   },
#   {
#     "name": "風扇",
#     "model": "julun.switch.jlsw01",
#     "did": "372816761",
#     "token": "c3e91cbdbfb7ea494c407746fcf56119"
#   },
#   {
#     "name": "風扇",
#     "model": "julun.switch.jlsw01",
#     "did": "372816782",
#     "token": "0f7dd5c4bd5fd36f0f85187d7da8c95c"
#   },
#   {
#     "name": "循環扇",
#     "model": "julun.switch.jlsw01",
#     "did": "372817143",
#     "token": "f169921f238db53636b280967cdcb049"
#   },
#   {
#     "name": "顯示器",
#     "model": "julun.switch.jlsw01",
#     "did": "372817171",
#     "token": "e77d06faf33c805fa94434c5506be810"
#   },
#   {
#     "name": "頭頂燈",
#     "model": "julun.switch.jlsw01",
#     "did": "372818217",
#     "token": "80b70812635cb8dad0fb1993b95a7e4b"
#   },
#   {
#     "name": "風扇",
#     "model": "leshi.switch.v002",
#     "did": "392925812",
#     "token": "c44fe843a4818c09ce28fe59cb995960"
#   },
#   {
#     "name": "輔助間接燈",
#     "model": "leshi.switch.v002",
#     "did": "392925997",
#     "token": "f13a05cd5c7bd47265aa9d3a11e99a6a"
#   },
#   {
#     "name": "夜燈",
#     "model": "leshi.switch.v002",
#     "did": "392926101",
#     "token": "6fbf792b9691c13f245deec4e3095320"
#   },
#   {
#     "name": "後門燈",
#     "model": "leshi.switch.v002",
#     "did": "392926170",
#     "token": "6e84038396fdfdbf73bf2f1ee0886ed1"
#   },
#   {
#     "name": "工具燈",
#     "model": "leshi.switch.v002",
#     "did": "392926230",
#     "token": "71663357915e0f729b954af951ad06b0"
#   },
#   {
#     "name": "加熱器",
#     "model": "leshi.switch.v002",
#     "did": "394491137",
#     "token": "339376c1c160536a72d04901d280295a"
#   },
#   {
#     "name": "吊櫃燈",
#     "model": "leshi.switch.v002",
#     "did": "394491192",
#     "token": "205fcb78688f6df88d98c0d22ea229be"
#   },
#   {
#     "name": "走道燈",
#     "model": "leshi.switch.v002",
#     "did": "394494525",
#     "token": "8d78dd5b3d1b2fb50090d3cd73ffb552"
#   },
#   {
#     "name": "間接照明",
#     "model": "leshi.switch.v002",
#     "did": "394503071",
#     "token": "7b6f70ec948f919f201671b4047b249c"
#   },
#   {
#     "name": "小愛-浴室",
#     "model": "xiaomi.wifispeaker.lx06",
#     "did": "403073868",
#     "token": "6d424f7a66794673637a77494a5a3142"
#   },
#   {
#     "name": "小愛觸屏音箱",
#     "model": "xiaomi.wifispeaker.x08a",
#     "did": "566963971",
#     "token": "3668683130367032385661685478496b"
#   },
#   {
#     "name": "小愛-工作室",
#     "model": "xiaomi.wifispeaker.lx06",
#     "did": "604128284",
#     "token": "51347a32724e7762764f6a694c6b7333"
#   },
#   {
#     "name": "小愛-新莊儲藏室",
#     "model": "xiaomi.wifispeaker.l05c",
#     "did": "606912069",
#     "token": "b852cef863b5d36c0ccade01bae9a80c"
#   },
#   {
#     "name": "工作室監視器",
#     "model": "mijia.camera.v1",
#     "did": "68182525",
#     "token": "64377a354f3832463177516671336347"
#   },
#   {
#     "name": "小愛-新莊客廳",
#     "model": "xiaomi.wifispeaker.lx06",
#     "did": "726638831",
#     "token": "424b5834516871455758324d63745371"
#   },
#   {
#     "name": "大燈",
#     "model": "lemesh.switch.sw0c01",
#     "did": "734623942",
#     "token": "121e2f3c543f01c764badf1a012fb939"
#   },
#   {
#     "name": "露台三號燈",
#     "model": "lemesh.switch.sw0c01",
#     "did": "734624350",
#     "token": "d67e3b2b34db58732d440735947f48f3"
#   },
#   {
#     "name": "地燈",
#     "model": "lxzn.switch.cbcsmj",
#     "did": "735614781",
#     "token": "a7df42ae7f3ef810e1c2688adfef14dc"
#   },
#   {
#     "name": "小愛-車庫",
#     "model": "xiaomi.wifispeaker.lx06",
#     "did": "759655877",
#     "token": "593057414b4a6a58735a30514a4e4152"
#   },
#   {
#     "name": "掃地機器人",
#     "model": "roborock.vacuum.s5",
#     "did": "82863487",
#     "token": "796642393077474c547a33456f6f6a35"
#   },
#   {
#     "name": "監視器",
#     "model": "lxzn.switch.cbcsmj",
#     "did": "830222606",
#     "token": "fb87e3efbc346b0bdebe16e924a5c56e"
#   },
#   {
#     "name": "血壓計",
#     "model": "ihealth.bp.bpm1",
#     "did": "86864078",
#     "token": "c571aaf6f8f1e0cf6ccc60bc98d972df"
#   },
#   {
#     "name": "溫度計",
#     "model": "miaomiaoce.sensor_ht.t2",
#     "did": "blt.3.161c4g3a8lk00",
#     "token": "8EC181E82AF1B35680820610"
#   },
#   {
#     "name": "溫度計",
#     "model": "miaomiaoce.sensor_ht.t2",
#     "did": "blt.3.161c5fvt8e801",
#     "token": "db2d9af6d21a22327c9b082d"
#   },
#   {
#     "name": "溫度計",
#     "model": "miaomiaoce.sensor_ht.t2",
#     "did": "blt.3.16da5teuo5s00",
#     "token": "CBB1A1D15017FBD4C748D6C0"
#   },
#   {
#     "name": "門禁",
#     "model": "isa.magnet.dw2hl",
#     "did": "blt.3.16daa0urkeg00",
#     "token": "7B0D962B7AA276A8A1C24D3B"
#   },
#   {
#     "name": "溫度計",
#     "model": "miaomiaoce.sensor_ht.t2",
#     "did": "blt.3.16dgr14po5c01",
#     "token": "8167ABE16282B8D3360EA0AB"
#   },
#   {
#     "name": "快遞箱",
#     "model": "isa.magnet.dw2hl",
#     "did": "blt.3.16ro7l5ec5g00",
#     "token": "7cc30a6a8ba01c2e55a85ab2"
#   },
#   {
#     "name": "溫度計",
#     "model": "miaomiaoce.sensor_ht.t2",
#     "did": "blt.3.16rvgret05s00",
#     "token": "c447f991ef82bfa26bb08575"
#   },
#   {
#     "name": "感應器",
#     "model": "lumi.motion.bmgl01",
#     "did": "blt.3.16u8uukks5c01",
#     "token": "7d1db59f42832ee7ed9a6849"
#   },
#   {
#     "name": "溫度計",
#     "model": "miaomiaoce.sensor_ht.t2",
#     "did": "blt.3.188v8ap3oe400",
#     "token": "fd08cd3370e6007a054c557e"
#   },
#   {
#     "name": "門禁",
#     "model": "isa.magnet.dw2hl",
#     "did": "blt.3.1983tt3885c00",
#     "token": "07e683d7d6fe8b7fd477f931"
#   },
#   {
#     "name": "門禁",
#     "model": "isa.magnet.dw2hl",
#     "did": "blt.3.1d663i7qo5c01",
#     "token": "b2d46869211d6f957b2431d8"
#   },
#   {
#     "name": "溫度計",
#     "model": "miaomiaoce.sensor_ht.t2",
#     "did": "blt.3.1d6alt8sglg00",
#     "token": "51623c46f46150f8ec68a90d"
#   },
#   {
#     "name": "淋浴間門",
#     "model": "isa.magnet.dw2hl",
#     "did": "blt.3.1d93uoqo45s02",
#     "token": "64884997570ca9f9ea4b52b4"
#   },
#   {
#     "name": "溫度計",
#     "model": "miaomiaoce.sensor_ht.t2",
#     "did": "blt.3.1d9p9k0245g01",
#     "token": "ad46c533576b0c4e51afd943"
#   },
#   {
#     "name": "溫度計-房內",
#     "model": "miaomiaoce.sensor_ht.t2",
#     "did": "blt.3.1d9pb7gfke400",
#     "token": "1aa441dc544a58d8bf433179"
#   },
#   {
#     "name": "溫度計-櫃內",
#     "model": "miaomiaoce.sensor_ht.t2",
#     "did": "blt.3.1d9pccsm4e800",
#     "token": "5fa1688ae227833fbabda834"
#   },
#   {
#     "name": "書桌按鈕",
#     "model": "lumi.remote.mcn001",
#     "did": "blt.3.1da40jvnoec00",
#     "token": "986c6cef42088fc45537f61c"
#   },
#   {
#     "name": "三樓主浴",
#     "model": "isa.magnet.dw2hl",
#     "did": "blt.3.1dltgcn5g5g01",
#     "token": "56f4d404569a39debd3af7f1"
#   },
#   {
#     "name": "床邊偵測",
#     "model": "lumi.motion.bmgl01",
#     "did": "blt.3.1dltups7o5k00",
#     "token": "312723e1521525a8de3e401f"
#   },
#   {
#     "name": "三樓客浴",
#     "model": "isa.magnet.dw2hl",
#     "did": "blt.3.1dm8biq845o00",
#     "token": "75053e8e9ba0de2c5d037e8a"
#   },
#   {
#     "name": "溫度計",
#     "model": "miaomiaoce.sensor_ht.t2",
#     "did": "blt.3.1ga0ok9o44c05",
#     "token": "ee47a818425e2edf24c05d4f"
#   },
#   {
#     "name": "溫度計",
#     "model": "miaomiaoce.sensor_ht.t9",
#     "did": "blt.3.1hg3k08fs4k00",
#     "token": "ad5c2462a9b954bac2cc4e1c"
#   },
#   {
#     "name": "廚房門禁",
#     "model": "isa.magnet.dw2hl",
#     "did": "blt.3.1hmlmp48c4g02",
#     "token": "79771ba06678cb50f97b37b7"
#   },
#   {
#     "name": "感應器：玄關",
#     "model": "lumi.motion.bmgl01",
#     "did": "blt.3.1hmn42glskg00",
#     "token": "2a4a4f826e7fe3df8409e64f"
#   },
#   {
#     "name": "溫度計",
#     "model": "miaomiaoce.sensor_ht.t9",
#     "did": "blt.3.1i5stdi3okc00",
#     "token": "cd192e6d791743d96f2db091"
#   },
#   {
#     "name": "露台門禁",
#     "model": "isa.magnet.dw2hl",
#     "did": "blt.3.1i5sv4mu4kg00",
#     "token": "a95e7433672672499fe8f9fb"
#   },
#   {
#     "name": "香氛機",
#     "model": "szxzh.diffuser.v03",
#     "did": "blt.3.1j1f147ggkc00",
#     "token": "9107c831b85dad3fdcc489b6"
#   },
#   {
#     "name": "香氛機",
#     "model": "szxzh.diffuser.v03",
#     "did": "blt.3.1j1f27m18c400",
#     "token": "fdf6c78f6853b1480d8102ee"
#   },
#   {
#     "name": "大門門禁",
#     "model": "isa.magnet.dw2hl",
#     "did": "blt.3.1j2seo1dskc00",
#     "token": "358691c20b4b7234d908ab70"
#   },
#   {
#     "name": "飲水機濾芯",
#     "model": "lumi.flood.bmcn01",
#     "did": "blt.3.1j2shcmeokc00",
#     "token": "2b3841e6747ea0d9318aa6af"
#   },
#   {
#     "name": "香氛機",
#     "model": "szxzh.diffuser.v03",
#     "did": "blt.3.1j7tu6tl04g03",
#     "token": "384efb93d3b23c452aab1bfc"
#   },
#   {
#     "name": "香氛機",
#     "model": "szxzh.diffuser.v03",
#     "did": "blt.3.1j7u38g38c401",
#     "token": "6f8ee4ffbe902d497666d4a4"
#   },
#   {
#     "name": "香氛機",
#     "model": "szxzh.diffuser.v03",
#     "did": "blt.3.1j7u4b1b0cc00",
#     "token": "0433877b0062b54652f33bdc"
#   },
#   {
#     "name": "感應器：浴室",
#     "model": "xiaomi.motion.pir1",
#     "did": "blt.3.1jdqdmd60kc00",
#     "token": "958076968184f0873f6578ab"
#   },
#   {
#     "name": "偵測器：洗衣間",
#     "model": "xiaomi.motion.pir1",
#     "did": "blt.3.1jdqnl0l4co01",
#     "token": "4911e7f957b9985cbe8816b8"
#   },
#   {
#     "name": "機上盒",
#     "model": "miir.stb.ir01",
#     "did": "ir.1263422401476218880",
#     "token": ""
#   },
#   {
#     "name": "電視",
#     "model": "miir.tv.ir01",
#     "did": "ir.1281910130288021504",
#     "token": ""
#   },
#   {
#     "name": "空氣濾清器",
#     "model": "miir.airpurifier.ir01",
#     "did": "ir.1281912558353313792",
#     "token": ""
#   },
#   {
#     "name": "蘋果遙控器",
#     "model": "miir.remote.ir01",
#     "did": "ir.1282023664073760769",
#     "token": ""
#   },
#   {
#     "name": "藍牙喇叭",
#     "model": "miir.remote.ir01",
#     "did": "ir.1386513547030355968",
#     "token": ""
#   },
#   {
#     "name": "客廳空調",
#     "model": "miir.aircondition.ir02",
#     "did": "ir.1394263600738258944",
#     "token": ""
#   },
#   {
#     "name": "空調",
#     "model": "miir.aircondition.ir02",
#     "did": "ir.1394279105792487425",
#     "token": ""
#   },
#   {
#     "name": "空調",
#     "model": "miir.aircondition.ir02",
#     "did": "ir.1394657225552879616",
#     "token": ""
#   },
#   {
#     "name": "馬桶",
#     "model": "miir.remote.ir01",
#     "did": "ir.1399947673700085760",
#     "token": ""
#   },
#   {
#     "name": "电视",
#     "model": "miir.tv.ir01",
#     "did": "ir.1424699826272133121",
#     "token": ""
#   },
#   {
#     "name": "空調",
#     "model": "miir.aircondition.ir02",
#     "did": "ir.1632582771749097472",
#     "token": ""
#   },
#   {
#     "name": "空調",
#     "model": "miir.remote.ir01",
#     "did": "ir.1784597737934307328",
#     "token": ""
#   },
#   {
#     "name": "空調",
#     "model": "miir.aircondition.ir02",
#     "did": "ir.1784607495516479488",
#     "token": ""
#   },
#   {
#     "name": "儲藏室空調",
#     "model": "miir.remote.ir01",
#     "did": "ir.1803366798063190016",
#     "token": ""
#   },
#   {
#     "name": "客廳空調",
#     "model": "miir.remote.ir01",
#     "did": "ir.1808434735530774528",
#     "token": ""
#   },
#   {
#     "name": "空調",
#     "model": "miir.aircondition.ir02",
#     "did": "ir.1836126318262370304",
#     "token": ""
#   },
#   {
#     "name": "Aqara水浸傳感器",
#     "model": "lumi.sensor_wleak.aq1",
#     "did": "lumi.158d0008652b60",
#     "token": ""
#   }
# ]

# %% [markdown]
# 篩選小愛音箱 pro

# %%
# !micli.py list | sed 's/\x1b\[[0-9;]*m//g' | jq '.[] | select(.model == "xiaomi.wifispeaker.lx06")'
# Out:
# {
#   "name": "小愛-地下室",
#   "model": "xiaomi.wifispeaker.lx06",
#   "did": "319695299",
#   "token": "7044516455505337514461596b645037"
# }
# {
#   "name": "小愛-客廳",
#   "model": "xiaomi.wifispeaker.lx06",
#   "did": "319865370",
#   "token": "6a5131545736327550786f6e43657257"
# }
# {
#   "name": "小愛-浴室",
#   "model": "xiaomi.wifispeaker.lx06",
#   "did": "403073868",
#   "token": "6d424f7a66794673637a77494a5a3142"
# }
# {
#   "name": "小愛-工作室",
#   "model": "xiaomi.wifispeaker.lx06",
#   "did": "604128284",
#   "token": "51347a32724e7762764f6a694c6b7333"
# }
# {
#   "name": "小愛-新莊客廳",
#   "model": "xiaomi.wifispeaker.lx06",
#   "did": "726638831",
#   "token": "424b5834516871455758324d63745371"
# }
# {
#   "name": "小愛-車庫",
#   "model": "xiaomi.wifispeaker.lx06",
#   "did": "759655877",
#   "token": "593057414b4a6a58735a30514a4e4152"
# }

# %% [markdown]
# 輸出全部設備到 Excel 文件

# %%
import json
import pandas as pd
import subprocess

# 定義輸出文件的名稱
_OUTPUT = "device_data.xlsx"
# 預設輸出引擎
_ENGINE = "openpyxl"
# 預設分頁名稱
_DEVICE = "Device Data"


# 1. 運行 micli.py list 的函數，傳出 JSON
def run_micli_list():
    try:
        # 調用 micli.py list 並輸出設備查詢結果
        result = subprocess.run(
            # 假設 micli.py 與本代碼在同一目錄
            ["micli.py", "list"],
            capture_output=True,
            text=True
        )

        # 確認是否成功執行命令
        if result.returncode != 0:
            print(f"micli.py 執行失敗: {result.stderr}")
            return []

        # 解析 micli.py 返回的 JSON 數據
        devices = json.loads(result.stdout)
        return devices

    except Exception as e:
        print(f"運行 micli.py list 時出錯: {e}")
        return []

# 2. 將設備數據寫入 Excel 的函數
def write_to_excel(devices, output_file=_OUTPUT):
    if not devices:
        print("無法掃描到任何設備。")
        return

    # 預處理設備資料，處理缺失的字段
    processed_devices = []
    for device in devices:
        device["model"] = device.get("model", "Unknown Model")
        device["name"] = device.get("name", "Unknown Name")
        device["type"] = device.get("type", "Unknown Type")
        processed_devices.append(device)

    # 將設備資料轉換為 DataFrame
    df = pd.DataFrame(processed_devices)

    # 主資料表：包含完整設備資料
    with pd.ExcelWriter(output_file, engine=_ENGINE) as writer:
        # 寫入主資料表
        df.to_excel(writer, index=False, sheet_name=_DEVICE)

    print(f"資料已成功寫入 {output_file}")

# 3. 主程序
def main():
    print("正在掃描設備...")
    devices = run_micli_list()
    if devices:
        print(f"掃描到 {len(devices)} 個設備。")
        write_to_excel(devices)
    else:
        print("未掃描到任何設備，請檢查帳戶或網絡設置。")

if __name__ == "__main__":
    main()
# Out:
# 正在掃描設備...
# 掃描到 144 個設備。
# 資料已成功寫入 device_data.xlsx

# %% [markdown]
# 使用內建函數

# %%
from miservice import MiAccount, MiNAService
import asyncio
from aiohttp import ClientSession
import os
# 解決嵌套事件循環問題
import nest_asyncio

# 輸出文件
_OUTPUT = "device_data_detail.xlsx"
# 預設輸出引擎
_ENGINE = "openpyxl"
# 預設分頁名稱
_DEVICE = "Device Data"

# 解決嵌套事件循環問題
nest_asyncio.apply()

# 1. 掃描設備的函數
async def scan_devices():
    try:
        env_get = os.environ.get
        store = os.path.join(os.path.expanduser("~"), ".mi.token")
        async with ClientSession() as session:
            account = MiAccount(
                session,
                env_get("MI_USER"), 
                env_get("MI_PASS"), 
                store
            )
            service = MiNAService(account)
            # 使用內建的函數取得設備清單
            devices = await service.device_list()
            return devices
    except Exception as e:
        print(f"設備掃描失敗: {e}")
        return []

# 2. 寫入 Excel 的函數
def write_to_excel(devices, output_file=_OUTPUT):
    if not devices:
        print("無法掃描到任何設備。")
        return

    # 預處理設備資料，處理缺失的 model 和 name 欄位
    processed_devices = []
    for device in devices:
        device["model"] = device.get("model", "Unknown Model")
        device["name"] = device.get("name", "Unknown Name")
        processed_devices.append(device)

    # 將設備資料轉換為 DataFrame
    df = pd.DataFrame(processed_devices)

    # 主資料表：包含完整設備資料
    with pd.ExcelWriter(output_file, engine=_ENGINE) as writer:
        # 寫入主資料表
        df.to_excel(
            writer,
            index=False,
            sheet_name=_DEVICE
        )
    print(f"資料已成功寫入 {output_file}")

# 3. 主程序
async def main():
    print("正在掃描設備...")
    devices = await scan_devices()
    if devices:
        print(f"掃描到 {len(devices)} 個設備。")
        write_to_excel(devices)
    else:
        print("未掃描到任何設備，請檢查賬戶或網絡設置。")

if __name__ == "__main__":
    # 確保環境變數已設置
    if not os.getenv("MI_USER") or not os.getenv("MI_PASS"):
        print("請先設置環境變數 MI_USER 和 MI_PASS，然後重新運行腳本。")
    else:
        # 在 Jupyter Notebook 或其他事件循環環境中運行
        asyncio.run(main())
# Out:
# 正在掃描設備...
# 掃描到 10 個設備。
# 資料已成功寫入 device_data_detail.xlsx

# %% [markdown]
# 基本說話

# %%
# !micli.py 5-1 您好
# Out:
# 0
